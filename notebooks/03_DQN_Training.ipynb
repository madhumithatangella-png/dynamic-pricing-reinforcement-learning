# %%
import sys
from pathlib import Path

# Add the project root to Python path
PROJECT_ROOT = Path().resolve().parent
sys.path.append(str(PROJECT_ROOT))

# %%
pip install numpy pandas matplotlib seaborn scikit-learn scipy torch torchvision torchaudio gymnasium stable-baselines3 jupyter notebook ipykernel tqdm joblib pyyaml pillow opencv-python plotly tensorboard openpyxl xgboost lightgbm catboost gym pygame
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000019C426146E0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/seaborn/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000019C425CE710>: Failed to establish a new connection: [WinError 10051] A socket operation was attempted to an unreachable network')': /simple/seaborn/
# ...

# %%
from src.rl.environment import HotelPricingEnvironment

# %%
from pathlib import Path

# Project root (parent of the notebooks folder)
PROJECT_ROOT = Path.cwd().parent
FEATURES_DATA_PATH = PROJECT_ROOT / "data" / "processed" / "features.csv"

# %%
from src.rl.demand_simulator import DemandSimulator

# %%
demand_sim = DemandSimulator()
